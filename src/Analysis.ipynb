# %% [markdown]
# # Data Model: `wx_data`

# %%
import os
from typing import Optional
from pathlib import Path
from datetime import datetime
from joblib import cpu_count, Parallel, delayed
import pandas as pd
from sqlmodel import SQLModel, Field, create_engine

# functions
def read_wxdata(FILE: Path) -> pd.DataFrame:
    """
    Read the wx_data.
    Input:
    - FILENAME: Path (from pathlib) object of the path of a wx_data file

    Output:
    - DF: dataframe of a wx_data
    """
    cols = ["date", "tmax", "tmin", "precip"]
    dtyp  = (str, int, int, int)
    dtypes  = {k:v for k, v in zip(cols, dtyp)}
    DF = pd.read_table(FILE,
                       delimiter = "\t",
                       header = None,
                       names  = cols, 
                       dtype  = dtypes)
    # Make time datetime obj
    DF["date"] = pd.to_datetime(DF["date"])
    # Assign a column for the site ID from the filename
    DF = DF.assign(site_id = FILE.stem)
    # Sanitize the null values
    DF = DF.replace(-9999, pd.NA)
    # print(df[df.isna().any(axis = 1)].head(3))
    return DF

# %%
dir_wxdata = Path("/code/wx_data/")
# Let's work on one file(
f_wxdata      = [f for f in dir_wxdata.glob("*")][0]
df = read_wxdata(f_wxdata)
print(df.head(3))
# Out:
#         date  tmax  tmin precip      site_id
# 0 1985-01-01   -22  -128     94  USC00110072
# 1 1985-01-02  -122  -217      0  USC00110072
# 2 1985-01-03  -106  -244      0  USC00110072

# %%
# %%time
dfall = Parallel(n_jobs = cpu_count() - 1)(delayed(read_wxdata)(f) for f in dir_wxdata.glob("USC*.txt"))
dfall = pd.concat(dfall)
# Out:
# CPU times: user 598 ms, sys: 208 ms, total: 806 ms
# Wall time: 3.46 s

# %% [markdown]
# ## Create Data Model

# %%
# models.py
class WxTable(SQLModel, table = True):
    id: Optional[int] = Field(default = None, primary_key = True)
    site_id: str
    date:    datetime
    tmax:    int | None
    tmin:    int | None
    precip:  int | None

# app.py
# Create db engine
engine = create_engine(os.environ["DATABASE_URL"], echo = True)
SQLModel.metadata.create_all(engine)
# if we suffer a collation mismatch, it might due to previously using a different postgres and not deleting the volume.
# run the code below:
# > podman-compose down
# > podman volume ls # to find the name of the volume
# > podman volume rm <name-of-volume>
# > podman-compose up -d
# Out:
# 2026-01-19 02:52:15,276 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-01-19 02:52:15,278 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-01-19 02:52:15,281 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-01-19 02:52:15,283 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-01-19 02:52:15,287 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-01-19 02:52:15,288 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-01-19 02:52:15,291 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-19 02:52:15,297 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-01-19 02:52:15,298 INFO sqlalchemy.engine.Engine [generated in 0.00103s] {'table_name': 'wxtable', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-01-19 02:52:15,302 INFO sqlalchemy.engine.Engine
# CREATE TABLE wxtable (
# 	id SERIAL NOT NULL,
# 	site_id VARCHAR NOT NULL,
# 	date TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	tmax INTEGER,
# 	tmin INTEGER,
# 	precip INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2026-01-19 02:52:15,303 INFO sqlalchemy.engine.Engine [no key 0.00082s] {}
# 2026-01-19 02:52:15,307 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Verify database
from sqlalchemy import inspect
inspector = inspect(engine)
inspector.has_table("wxtable")
# Out:
# 2026-01-19 02:54:58,387 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-19 02:54:58,390 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-01-19 02:54:58,394 INFO sqlalchemy.engine.Engine [cached since 163.1s ago] {'table_name': 'wxtable', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-01-19 02:54:58,398 INFO sqlalchemy.engine.Engine ROLLBACK
# True

# %% [markdown]
# ## Using scripts

# %%
from main import main
main()
# Out:
# 2026-01-20 17:37:24,855 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2026-01-20 17:37:24,856 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-01-20 17:37:24,858 INFO sqlalchemy.engine.Engine select current_schema()
# 2026-01-20 17:37:24,859 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-01-20 17:37:24,861 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2026-01-20 17:37:24,861 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-01-20 17:37:24,863 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-20 17:37:24,867 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-01-20 17:37:24,868 INFO sqlalchemy.engine.Engine [generated in 0.00104s] {'table_name': 'wxtable', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-01-20 17:37:24,871 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-01-20 17:37:24,872 INFO sqlalchemy.engine.Engine [cached since 0.005061s ago] {'table_name': 'wxtablestats', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-01-20 17:37:24,875 INFO sqlalchemy.engine.Engine
# DROP TABLE wxtablestats
# 2026-01-20 17:37:24,876 INFO sqlalchemy.engine.Engine [no key 0.00120s] {}
# 2026-01-20 17:37:24,881 INFO sqlalchemy.engine.Engine
# DROP TABLE wxtable
# 2026-01-20 17:37:24,882 INFO sqlalchemy.engine.Engine [no key 0.00090s] {}
# 2026-01-20 17:37:24,885 INFO sqlalchemy.engine.Engine COMMIT
# 2026-01-20 17:37:24,915 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-20 17:37:24,915 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-01-20 17:37:24,916 INFO sqlalchemy.engine.Engine [cached since 0.04872s ago] {'table_name': 'wxtable', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-01-20 17:37:24,918 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-01-20 17:37:24,919 INFO sqlalchemy.engine.Engine [cached since 0.05118s ago] {'table_name': 'wxtablestats', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-01-20 17:37:24,920 INFO sqlalchemy.engine.Engine
# CREATE TABLE wxtable (
# 	id SERIAL NOT NULL,
# 	site_id VARCHAR NOT NULL,
# 	date TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	tmax INTEGER,
# 	tmin INTEGER,
# 	precip INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2026-01-20 17:37:24,921 INFO sqlalchemy.engine.Engine [no key 0.00068s] {}
# 2026-01-20 17:37:24,926 INFO sqlalchemy.engine.Engine
# CREATE TABLE wxtablestats (
# 	id SERIAL NOT NULL,
# 	site_id VARCHAR NOT NULL,
# 	year TIMESTAMP WITHOUT TIME ZONE NOT NULL,
# 	tmax_yearly INTEGER,
# 	tmin_yearly INTEGER,
# 	precip_yearly INTEGER,
# 	PRIMARY KEY (id)
# )
#
#
# 2026-01-20 17:37:24,927 INFO sqlalchemy.engine.Engine [no key 0.00084s] {}
# 2026-01-20 17:37:24,929 INFO sqlalchemy.engine.Engine COMMIT
# 2026-01-20 17:37:24,976 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-20 17:37:24,979 INFO sqlalchemy.engine.Engine INSERT INTO wxtablestats (site_id, year, tmax_yearly, tmin_yearly, precip_yearly) VALUES (%(site_id__0)s, %(year__0)s, %(tmax_yearly__0)s, %(tmin_yearly__0)s, %(precip_yearly__0)s), (%(site_id__1)s, %(year__1)s, %(tmax_yearly__1)s, %(tmin_yearly__1)s ... 2627 characters truncated ... s), (%(site_id__29)s, %(year__29)s, %(tmax_yearly__29)s, %(tmin_yearly__29)s, %(precip_yearly__29)s)
# 2026-01-20 17:37:24,979 INFO sqlalchemy.engine.Engine [generated in 0.00012s (insertmanyvalues) 1/1 (unordered)] {'year__0': Timestamp('1985-01-01 00:00:00'), 'tmin_yearly__0': 43.264462809917354, 'site_id__0': 'USC00110072', 'precip_yearly__0': 7801, 'tmax_yearly__0': 153.34794520547945, 'year__1': Timestamp('1986-01-01 00:00:00'), 'tmin_yearly__1': 21.761904761904763, 'site_id__1': 'USC00110072', 'precip_yearly__1': 5053, 'tmax_yearly__1': 126.96336996336996, 'year__2': Timestamp('1987-01-01 00:00:00'), 'tmin_yearly__2': 63.298630136986304, 'site_id__2': 'USC00110072', 'precip_yearly__2': 7936, 'tmax_yearly__2': 177.6027397260274, 'year__3': Timestamp('1988-01-01 00:00:00'), 'tmin_yearly__3': 45.349726775956285, 'site_id__3': 'USC00110072', 'precip_yearly__3': 5410, 'tmax_yearly__3': 173.47267759562843, 'year__4': Timestamp('1989-01-01 00:00:00'), 'tmin_yearly__4': 39.83561643835616, 'site_id__4': 'USC00110072', 'precip_yearly__4': 7937, 'tmax_yearly__4': 156.5150684931507, 'year__5': Timestamp('1990-01-01 00:00:00'), 'tmin_yearly__5': 59.602739726027394, 'site_id__5': 'USC00110072', 'precip_yearly__5': 11694, 'tmax_yearly__5': 169.0027397260274, 'year__6': Timestamp('1991-01-01 00:00:00'), 'tmin_yearly__6': 52.612994350282484, 'site_id__6': 'USC00110072', 'precip_yearly__6': 7906, 'tmax_yearly__6': 164.1596638655462, 'year__7': Timestamp('1992-01-01 00:00:00'), 'tmin_yearly__7': 50.37845303867403, 'site_id__7': 'USC00110072', 'precip_yearly__7': 9326, 'tmax_yearly__7': 149.91735537190084, 'year__8': Timestamp('1993-01-01 00:00:00'), 'tmin_yearly__8': 47.45325779036827, 'site_id__8': 'USC00110072', 'precip_yearly__8': 14207, 'tmax_yearly__8': 139.5966386554622, 'year__9': Timestamp('1994-01-01 00:00:00'), 'tmin_yearly__9': 37.8941504178273, 'site_id__9': 'USC00110072', 'precip_yearly__9': 6688, 'tmax_yearly__9': 149.60955056179776 ... 50 parameters truncated ... 'year__20': Timestamp('2005-01-01 00:00:00'), 'tmin_yearly__20': 47.00859598853868, 'site_id__20': 'USC00110072', 'precip_yearly__20': 6477, 'tmax_yearly__20': 161.6281690140845, 'year__21': Timestamp('2006-01-01 00:00:00'), 'tmin_yearly__21': 51.401685393258425, 'site_id__21': 'USC00110072', 'precip_yearly__21': 8008, 'tmax_yearly__21': 161.8498583569405, 'year__22': Timestamp('2007-01-01 00:00:00'), 'tmin_yearly__22': 41.48997134670487, 'site_id__22': 'USC00110072', 'precip_yearly__22': 8903, 'tmax_yearly__22': 155.22766570605188, 'year__23': Timestamp('2008-01-01 00:00:00'), 'tmin_yearly__23': 29.108635097493035, 'site_id__23': 'USC00110072', 'precip_yearly__23': 12719, 'tmax_yearly__23': 143.45042492917847, 'year__24': Timestamp('2009-01-01 00:00:00'), 'tmin_yearly__24': 37.72394366197183, 'site_id__24': 'USC00110072', 'precip_yearly__24': 13438, 'tmax_yearly__24': 144.04815864022663, 'year__25': Timestamp('2010-01-01 00:00:00'), 'tmin_yearly__25': 45.725903614457835, 'site_id__25': 'USC00110072', 'precip_yearly__25': 11454, 'tmax_yearly__25': 153.19277108433735, 'year__26': Timestamp('2011-01-01 00:00:00'), 'tmin_yearly__26': 45.38904109589041, 'site_id__26': 'USC00110072', 'precip_yearly__26': 8573, 'tmax_yearly__26': 154.1123287671233, 'year__27': Timestamp('2012-01-01 00:00:00'), 'tmin_yearly__27': 54.04120879120879, 'site_id__27': 'USC00110072', 'precip_yearly__27': 7450, 'tmax_yearly__27': 173.94230769230768, 'year__28': Timestamp('2013-01-01 00:00:00'), 'tmin_yearly__28': 35.05865921787709, 'site_id__28': 'USC00110072', 'precip_yearly__28': 8114, 'tmax_yearly__28': 152.62569832402235, 'year__29': Timestamp('2014-01-01 00:00:00'), 'tmin_yearly__29': 23.70718232044199, 'site_id__29': 'USC00110072', 'precip_yearly__29': 9863, 'tmax_yearly__29': 138.04972375690608}
# 2026-01-20 17:37:25,035 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 2048 characters truncated ... __29)s, %(precip__29)s), (%(site_id__30)s, %(date__30)s, %(tmax__30)s, %(tmin__30)s, %(precip__30)s)
# 2026-01-20 17:37:25,035 INFO sqlalchemy.engine.Engine [generated in 0.00019s (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('1985-01-01 00:00:00'), 'tmin__0': -128, 'precip__0': 94, 'tmax__0': -22, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1985-01-02 00:00:00'), 'tmin__1': -217, 'precip__1': 0, 'tmax__1': -122, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1985-01-03 00:00:00'), 'tmin__2': -244, 'precip__2': 0, 'tmax__2': -106, 'site_id__2': 'USC00110072', 'date__3': Timestamp('1985-01-04 00:00:00'), 'tmin__3': -189, 'precip__3': 0, 'tmax__3': -56, 'site_id__3': 'USC00110072', 'date__4': Timestamp('1985-01-05 00:00:00'), 'tmin__4': -78, 'precip__4': 0, 'tmax__4': 11, 'site_id__4': 'USC00110072', 'date__5': Timestamp('1985-01-06 00:00:00'), 'tmin__5': -50, 'precip__5': 0, 'tmax__5': 28, 'site_id__5': 'USC00110072', 'date__6': Timestamp('1985-01-07 00:00:00'), 'tmin__6': -11, 'precip__6': 0, 'tmax__6': 22, 'site_id__6': 'USC00110072', 'date__7': Timestamp('1985-01-08 00:00:00'), 'tmin__7': -106, 'precip__7': 0, 'tmax__7': -6, 'site_id__7': 'USC00110072', 'date__8': Timestamp('1985-01-09 00:00:00'), 'tmin__8': -100, 'precip__8': 0, 'tmax__8': -22, 'site_id__8': 'USC00110072', 'date__9': Timestamp('1985-01-10 00:00:00'), 'tmin__9': -106, 'precip__9': 15, 'tmax__9': -39, 'site_id__9': 'USC00110072' ... 55 parameters truncated ... 'date__21': Timestamp('1985-01-22 00:00:00'), 'tmin__21': -106, 'precip__21': 0, 'tmax__21': -39, 'site_id__21': 'USC00110072', 'date__22': Timestamp('1985-01-23 00:00:00'), 'tmin__22': -94, 'precip__22': 0, 'tmax__22': -17, 'site_id__22': 'USC00110072', 'date__23': Timestamp('1985-01-24 00:00:00'), 'tmin__23': -39, 'precip__23': 23, 'tmax__23': -6, 'site_id__23': 'USC00110072', 'date__24': Timestamp('1985-01-25 00:00:00'), 'tmin__24': -156, 'precip__24': 0, 'tmax__24': 0, 'site_id__24': 'USC00110072', 'date__25': Timestamp('1985-01-26 00:00:00'), 'tmin__25': -200, 'precip__25': 0, 'tmax__25': -61, 'site_id__25': 'USC00110072', 'date__26': Timestamp('1985-01-27 00:00:00'), 'tmin__26': -83, 'precip__26': 0, 'tmax__26': 0, 'site_id__26': 'USC00110072', 'date__27': Timestamp('1985-01-28 00:00:00'), 'tmin__27': -172, 'precip__27': 0, 'tmax__27': -44, 'site_id__27': 'USC00110072', 'date__28': Timestamp('1985-01-29 00:00:00'), 'tmin__28': -150, 'precip__28': 0, 'tmax__28': -33, 'site_id__28': 'USC00110072', 'date__29': Timestamp('1985-01-30 00:00:00'), 'tmin__29': -106, 'precip__29': 13, 'tmax__29': -22, 'site_id__29': 'USC00110072', 'date__30': Timestamp('1985-01-31 00:00:00'), 'tmin__30': -222, 'precip__30': 0, 'tmax__30': -100, 'site_id__30': 'USC00110072'}
# 2026-01-20 17:37:25,038 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, precip) VALUES (%(site_id)s, %(date)s, %(tmax)s, %(precip)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,039 INFO sqlalchemy.engine.Engine [generated in 0.00114s] {'site_id': 'USC00110072', 'date': Timestamp('1985-02-01 00:00:00'), 'tmax': -83, 'precip': 0}
# 2026-01-20 17:37:25,041 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 6360 characters truncated ... __85)s, %(precip__85)s), (%(site_id__86)s, %(date__86)s, %(tmax__86)s, %(tmin__86)s, %(precip__86)s)
# 2026-01-20 17:37:25,042 INFO sqlalchemy.engine.Engine [cached since 0.006365s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('1985-02-02 00:00:00'), 'tmin__0': -211, 'precip__0': 0, 'tmax__0': -128, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1985-02-03 00:00:00'), 'tmin__1': -200, 'precip__1': 0, 'tmax__1': -61, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1985-02-04 00:00:00'), 'tmin__2': -133, 'precip__2': 0, 'tmax__2': -67, 'site_id__2': 'USC00110072', 'date__3': Timestamp('1985-02-05 00:00:00'), 'tmin__3': -100, 'precip__3': 20, 'tmax__3': -33, 'site_id__3': 'USC00110072', 'date__4': Timestamp('1985-02-06 00:00:00'), 'tmin__4': -178, 'precip__4': 0, 'tmax__4': -72, 'site_id__4': 'USC00110072', 'date__5': Timestamp('1985-02-07 00:00:00'), 'tmin__5': -211, 'precip__5': 0, 'tmax__5': -100, 'site_id__5': 'USC00110072', 'date__6': Timestamp('1985-02-08 00:00:00'), 'tmin__6': -233, 'precip__6': 0, 'tmax__6': -72, 'site_id__6': 'USC00110072', 'date__7': Timestamp('1985-02-09 00:00:00'), 'tmin__7': -139, 'precip__7': 0, 'tmax__7': -44, 'site_id__7': 'USC00110072', 'date__8': Timestamp('1985-02-10 00:00:00'), 'tmin__8': -50, 'precip__8': 25, 'tmax__8': -22, 'site_id__8': 'USC00110072', 'date__9': Timestamp('1985-02-11 00:00:00'), 'tmin__9': -50, 'precip__9': 30, 'tmax__9': -22, 'site_id__9': 'USC00110072' ... 335 parameters truncated ... 'date__77': Timestamp('1985-04-20 00:00:00'), 'tmin__77': 172, 'precip__77': 0, 'tmax__77': 294, 'site_id__77': 'USC00110072', 'date__78': Timestamp('1985-04-21 00:00:00'), 'tmin__78': 172, 'precip__78': 0, 'tmax__78': 294, 'site_id__78': 'USC00110072', 'date__79': Timestamp('1985-04-22 00:00:00'), 'tmin__79': 183, 'precip__79': 0, 'tmax__79': 278, 'site_id__79': 'USC00110072', 'date__80': Timestamp('1985-04-23 00:00:00'), 'tmin__80': 167, 'precip__80': 51, 'tmax__80': 256, 'site_id__80': 'USC00110072', 'date__81': Timestamp('1985-04-24 00:00:00'), 'tmin__81': 94, 'precip__81': 0, 'tmax__81': 206, 'site_id__81': 'USC00110072', 'date__82': Timestamp('1985-04-25 00:00:00'), 'tmin__82': 78, 'precip__82': 0, 'tmax__82': 217, 'site_id__82': 'USC00110072', 'date__83': Timestamp('1985-04-26 00:00:00'), 'tmin__83': 94, 'precip__83': 0, 'tmax__83': 272, 'site_id__83': 'USC00110072', 'date__84': Timestamp('1985-04-27 00:00:00'), 'tmin__84': 83, 'precip__84': 13, 'tmax__84': 239, 'site_id__84': 'USC00110072', 'date__85': Timestamp('1985-04-28 00:00:00'), 'tmin__85': 72, 'precip__85': 0, 'tmax__85': 217, 'site_id__85': 'USC00110072', 'date__86': Timestamp('1985-04-29 00:00:00'), 'tmin__86': 33, 'precip__86': 0, 'tmax__86': 261, 'site_id__86': 'USC00110072'}
# 2026-01-20 17:37:25,045 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, precip) VALUES (%(site_id)s, %(date)s, %(tmax)s, %(precip)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,046 INFO sqlalchemy.engine.Engine [cached since 0.008247s ago] {'site_id': 'USC00110072', 'date': Timestamp('1985-04-30 00:00:00'), 'tmax': 244, 'precip': 58}
# 2026-01-20 17:37:25,061 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 81161 characters truncated ... , %(precip__998)s), (%(site_id__999)s, %(date__999)s, %(tmax__999)s, %(tmin__999)s, %(precip__999)s)
# 2026-01-20 17:37:25,062 INFO sqlalchemy.engine.Engine [cached since 0.02463s ago (insertmanyvalues) 1/3 (unordered)] {'date__0': Timestamp('1985-05-01 00:00:00'), 'tmin__0': 111, 'precip__0': 20, 'tmax__0': 172, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1985-05-02 00:00:00'), 'tmin__1': 50, 'precip__1': 0, 'tmax__1': 211, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1985-05-03 00:00:00'), 'tmin__2': 44, 'precip__2': 0, 'tmax__2': 239, 'site_id__2': 'USC00110072', 'date__3': Timestamp('1985-05-04 00:00:00'), 'tmin__3': 106, 'precip__3': 0, 'tmax__3': 233, 'site_id__3': 'USC00110072', 'date__4': Timestamp('1985-05-05 00:00:00'), 'tmin__4': 144, 'precip__4': 0, 'tmax__4': 233, 'site_id__4': 'USC00110072', 'date__5': Timestamp('1985-05-06 00:00:00'), 'tmin__5': 144, 'precip__5': 0, 'tmax__5': 233, 'site_id__5': 'USC00110072', 'date__6': Timestamp('1985-05-07 00:00:00'), 'tmin__6': 106, 'precip__6': 0, 'tmax__6': 261, 'site_id__6': 'USC00110072', 'date__7': Timestamp('1985-05-08 00:00:00'), 'tmin__7': 122, 'precip__7': 0, 'tmax__7': 272, 'site_id__7': 'USC00110072', 'date__8': Timestamp('1985-05-09 00:00:00'), 'tmin__8': 139, 'precip__8': 0, 'tmax__8': 278, 'site_id__8': 'USC00110072', 'date__9': Timestamp('1985-05-10 00:00:00'), 'tmin__9': 139, 'precip__9': 0, 'tmax__9': 283, 'site_id__9': 'USC00110072' ... 4900 parameters truncated ... 'date__990': Timestamp('1988-04-17 00:00:00'), 'tmin__990': 44, 'precip__990': 0, 'tmax__990': 250, 'site_id__990': 'USC00110072', 'date__991': Timestamp('1988-04-18 00:00:00'), 'tmin__991': 11, 'precip__991': 0, 'tmax__991': 178, 'site_id__991': 'USC00110072', 'date__992': Timestamp('1988-04-19 00:00:00'), 'tmin__992': -33, 'precip__992': 0, 'tmax__992': 133, 'site_id__992': 'USC00110072', 'date__993': Timestamp('1988-04-20 00:00:00'), 'tmin__993': 39, 'precip__993': 0, 'tmax__993': 189, 'site_id__993': 'USC00110072', 'date__994': Timestamp('1988-04-21 00:00:00'), 'tmin__994': 0, 'precip__994': 0, 'tmax__994': 144, 'site_id__994': 'USC00110072', 'date__995': Timestamp('1988-04-22 00:00:00'), 'tmin__995': 50, 'precip__995': 0, 'tmax__995': 133, 'site_id__995': 'USC00110072', 'date__996': Timestamp('1988-04-23 00:00:00'), 'tmin__996': 22, 'precip__996': 0, 'tmax__996': 122, 'site_id__996': 'USC00110072', 'date__997': Timestamp('1988-04-24 00:00:00'), 'tmin__997': -17, 'precip__997': 0, 'tmax__997': 178, 'site_id__997': 'USC00110072', 'date__998': Timestamp('1988-04-25 00:00:00'), 'tmin__998': 67, 'precip__998': 0, 'tmax__998': 211, 'site_id__998': 'USC00110072', 'date__999': Timestamp('1988-04-26 00:00:00'), 'tmin__999': 83, 'precip__999': 0, 'tmax__999': 178, 'site_id__999': 'USC00110072'}
# 2026-01-20 17:37:25,084 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 81161 characters truncated ... , %(precip__998)s), (%(site_id__999)s, %(date__999)s, %(tmax__999)s, %(tmin__999)s, %(precip__999)s)
# 2026-01-20 17:37:25,085 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/3 (unordered)] {'date__0': Timestamp('1988-04-27 00:00:00'), 'tmin__0': 28, 'precip__0': 30, 'tmax__0': 128, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1988-04-28 00:00:00'), 'tmin__1': 22, 'precip__1': 0, 'tmax__1': 189, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1988-04-29 00:00:00'), 'tmin__2': 39, 'precip__2': 0, 'tmax__2': 217, 'site_id__2': 'USC00110072', 'date__3': Timestamp('1988-04-30 00:00:00'), 'tmin__3': 56, 'precip__3': 0, 'tmax__3': 244, 'site_id__3': 'USC00110072', 'date__4': Timestamp('1988-05-01 00:00:00'), 'tmin__4': 67, 'precip__4': 0, 'tmax__4': 256, 'site_id__4': 'USC00110072', 'date__5': Timestamp('1988-05-02 00:00:00'), 'tmin__5': 67, 'precip__5': 0, 'tmax__5': 261, 'site_id__5': 'USC00110072', 'date__6': Timestamp('1988-05-03 00:00:00'), 'tmin__6': 83, 'precip__6': 0, 'tmax__6': 256, 'site_id__6': 'USC00110072', 'date__7': Timestamp('1988-05-04 00:00:00'), 'tmin__7': 50, 'precip__7': 0, 'tmax__7': 228, 'site_id__7': 'USC00110072', 'date__8': Timestamp('1988-05-05 00:00:00'), 'tmin__8': 67, 'precip__8': 0, 'tmax__8': 256, 'site_id__8': 'USC00110072', 'date__9': Timestamp('1988-05-06 00:00:00'), 'tmin__9': 67, 'precip__9': 0, 'tmax__9': 278, 'site_id__9': 'USC00110072' ... 4900 parameters truncated ... 'date__990': Timestamp('1991-01-12 00:00:00'), 'tmin__990': -67, 'precip__990': 0, 'tmax__990': -17, 'site_id__990': 'USC00110072', 'date__991': Timestamp('1991-01-13 00:00:00'), 'tmin__991': -72, 'precip__991': 0, 'tmax__991': -11, 'site_id__991': 'USC00110072', 'date__992': Timestamp('1991-01-14 00:00:00'), 'tmin__992': -33, 'precip__992': 0, 'tmax__992': 56, 'site_id__992': 'USC00110072', 'date__993': Timestamp('1991-01-15 00:00:00'), 'tmin__993': -50, 'precip__993': 107, 'tmax__993': 0, 'site_id__993': 'USC00110072', 'date__994': Timestamp('1991-01-16 00:00:00'), 'tmin__994': -61, 'precip__994': 0, 'tmax__994': 6, 'site_id__994': 'USC00110072', 'date__995': Timestamp('1991-01-17 00:00:00'), 'tmin__995': -67, 'precip__995': 0, 'tmax__995': -6, 'site_id__995': 'USC00110072', 'date__996': Timestamp('1991-01-18 00:00:00'), 'tmin__996': -94, 'precip__996': 0, 'tmax__996': 6, 'site_id__996': 'USC00110072', 'date__997': Timestamp('1991-01-19 00:00:00'), 'tmin__997': -22, 'precip__997': 0, 'tmax__997': 56, 'site_id__997': 'USC00110072', 'date__998': Timestamp('1991-01-20 00:00:00'), 'tmin__998': -133, 'precip__998': 13, 'tmax__998': 33, 'site_id__998': 'USC00110072', 'date__999': Timestamp('1991-01-21 00:00:00'), 'tmin__999': -172, 'precip__999': 0, 'tmax__999': -106, 'site_id__999': 'USC00110072'}
# 2026-01-20 17:37:25,106 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 7607 characters truncated ... , %(precip__101)s), (%(site_id__102)s, %(date__102)s, %(tmax__102)s, %(tmin__102)s, %(precip__102)s)
# 2026-01-20 17:37:25,107 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/3 (unordered)] {'date__0': Timestamp('1991-01-22 00:00:00'), 'tmin__0': -222, 'precip__0': 0, 'tmax__0': -11, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1991-01-23 00:00:00'), 'tmin__1': -89, 'precip__1': 0, 'tmax__1': 11, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1991-01-24 00:00:00'), 'tmin__2': -167, 'precip__2': 0, 'tmax__2': -83, 'site_id__2': 'USC00110072', 'date__3': Timestamp('1991-01-25 00:00:00'), 'tmin__3': -183, 'precip__3': 8, 'tmax__3': -122, 'site_id__3': 'USC00110072', 'date__4': Timestamp('1991-01-26 00:00:00'), 'tmin__4': -161, 'precip__4': 0, 'tmax__4': -56, 'site_id__4': 'USC00110072', 'date__5': Timestamp('1991-01-27 00:00:00'), 'tmin__5': -139, 'precip__5': 0, 'tmax__5': -11, 'site_id__5': 'USC00110072', 'date__6': Timestamp('1991-01-28 00:00:00'), 'tmin__6': -89, 'precip__6': 0, 'tmax__6': 17, 'site_id__6': 'USC00110072', 'date__7': Timestamp('1991-01-29 00:00:00'), 'tmin__7': -117, 'precip__7': 0, 'tmax__7': -33, 'site_id__7': 'USC00110072', 'date__8': Timestamp('1991-01-30 00:00:00'), 'tmin__8': -194, 'precip__8': 0, 'tmax__8': -78, 'site_id__8': 'USC00110072', 'date__9': Timestamp('1991-01-31 00:00:00'), 'tmin__9': -144, 'precip__9': 0, 'tmax__9': -39, 'site_id__9': 'USC00110072' ... 415 parameters truncated ... 'date__93': Timestamp('1991-04-25 00:00:00'), 'tmin__93': 78, 'precip__93': 0, 'tmax__93': 167, 'site_id__93': 'USC00110072', 'date__94': Timestamp('1991-04-26 00:00:00'), 'tmin__94': 61, 'precip__94': 48, 'tmax__94': 256, 'site_id__94': 'USC00110072', 'date__95': Timestamp('1991-04-27 00:00:00'), 'tmin__95': 150, 'precip__95': 0, 'tmax__95': 250, 'site_id__95': 'USC00110072', 'date__96': Timestamp('1991-04-28 00:00:00'), 'tmin__96': 89, 'precip__96': 58, 'tmax__96': 244, 'site_id__96': 'USC00110072', 'date__97': Timestamp('1991-04-29 00:00:00'), 'tmin__97': 156, 'precip__97': 0, 'tmax__97': 250, 'site_id__97': 'USC00110072', 'date__98': Timestamp('1991-04-30 00:00:00'), 'tmin__98': 89, 'precip__98': 0, 'tmax__98': 194, 'site_id__98': 'USC00110072', 'date__99': Timestamp('1991-05-01 00:00:00'), 'tmin__99': 78, 'precip__99': 0, 'tmax__99': 178, 'site_id__99': 'USC00110072', 'date__100': Timestamp('1991-05-02 00:00:00'), 'tmin__100': 61, 'precip__100': 0, 'tmax__100': 228, 'site_id__100': 'USC00110072', 'date__101': Timestamp('1991-05-03 00:00:00'), 'tmin__101': 61, 'precip__101': 43, 'tmax__101': 172, 'site_id__101': 'USC00110072', 'date__102': Timestamp('1991-05-04 00:00:00'), 'tmin__102': 83, 'precip__102': 0, 'tmax__102': 200, 'site_id__102': 'USC00110072'}
# 2026-01-20 17:37:25,111 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s, %(tmin__2)s), (%(site_id__3)s, %(date__3)s, %(tmax__3)s, %(tmin__3)s)
# 2026-01-20 17:37:25,113 INFO sqlalchemy.engine.Engine [generated in 0.00014s (insertmanyvalues) 1/1 (unordered)] {'tmax__0': 172, 'site_id__0': 'USC00110072', 'date__0': Timestamp('1991-05-05 00:00:00'), 'tmin__0': 72, 'tmax__1': 94, 'site_id__1': 'USC00110072', 'date__1': Timestamp('1991-05-06 00:00:00'), 'tmin__1': 50, 'tmax__2': 200, 'site_id__2': 'USC00110072', 'date__2': Timestamp('1991-05-07 00:00:00'), 'tmin__2': 17, 'tmax__3': 206, 'site_id__3': 'USC00110072', 'date__3': Timestamp('1991-05-08 00:00:00'), 'tmin__3': 111}
# 2026-01-20 17:37:25,115 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 5436 characters truncated ... __73)s, %(precip__73)s), (%(site_id__74)s, %(date__74)s, %(tmax__74)s, %(tmin__74)s, %(precip__74)s)
# 2026-01-20 17:37:25,116 INFO sqlalchemy.engine.Engine [cached since 0.08038s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('1991-05-09 00:00:00'), 'tmin__0': 111, 'precip__0': 0, 'tmax__0': 250, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1991-05-10 00:00:00'), 'tmin__1': 117, 'precip__1': 0, 'tmax__1': 261, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1991-05-11 00:00:00'), 'tmin__2': 172, 'precip__2': 0, 'tmax__2': 283, 'site_id__2': 'USC00110072', 'date__3': Timestamp('1991-05-12 00:00:00'), 'tmin__3': 161, 'precip__3': 0, 'tmax__3': 294, 'site_id__3': 'USC00110072', 'date__4': Timestamp('1991-05-13 00:00:00'), 'tmin__4': 183, 'precip__4': 0, 'tmax__4': 311, 'site_id__4': 'USC00110072', 'date__5': Timestamp('1991-05-14 00:00:00'), 'tmin__5': 183, 'precip__5': 43, 'tmax__5': 311, 'site_id__5': 'USC00110072', 'date__6': Timestamp('1991-05-15 00:00:00'), 'tmin__6': 189, 'precip__6': 0, 'tmax__6': 272, 'site_id__6': 'USC00110072', 'date__7': Timestamp('1991-05-16 00:00:00'), 'tmin__7': 233, 'precip__7': 53, 'tmax__7': 256, 'site_id__7': 'USC00110072', 'date__8': Timestamp('1991-05-17 00:00:00'), 'tmin__8': 167, 'precip__8': 239, 'tmax__8': 283, 'site_id__8': 'USC00110072', 'date__9': Timestamp('1991-05-18 00:00:00'), 'tmin__9': 106, 'precip__9': 0, 'tmax__9': 150, 'site_id__9': 'USC00110072' ... 275 parameters truncated ... 'date__65': Timestamp('1991-07-13 00:00:00'), 'tmin__65': 183, 'precip__65': 0, 'tmax__65': 306, 'site_id__65': 'USC00110072', 'date__66': Timestamp('1991-07-14 00:00:00'), 'tmin__66': 167, 'precip__66': 0, 'tmax__66': 306, 'site_id__66': 'USC00110072', 'date__67': Timestamp('1991-07-15 00:00:00'), 'tmin__67': 156, 'precip__67': 0, 'tmax__67': 283, 'site_id__67': 'USC00110072', 'date__68': Timestamp('1991-07-16 00:00:00'), 'tmin__68': 139, 'precip__68': 0, 'tmax__68': 294, 'site_id__68': 'USC00110072', 'date__69': Timestamp('1991-07-17 00:00:00'), 'tmin__69': 150, 'precip__69': 0, 'tmax__69': 317, 'site_id__69': 'USC00110072', 'date__70': Timestamp('1991-07-18 00:00:00'), 'tmin__70': 183, 'precip__70': 0, 'tmax__70': 322, 'site_id__70': 'USC00110072', 'date__71': Timestamp('1991-07-19 00:00:00'), 'tmin__71': 183, 'precip__71': 0, 'tmax__71': 339, 'site_id__71': 'USC00110072', 'date__72': Timestamp('1991-07-20 00:00:00'), 'tmin__72': 217, 'precip__72': 0, 'tmax__72': 333, 'site_id__72': 'USC00110072', 'date__73': Timestamp('1991-07-21 00:00:00'), 'tmin__73': 217, 'precip__73': 0, 'tmax__73': 333, 'site_id__73': 'USC00110072', 'date__74': Timestamp('1991-07-22 00:00:00'), 'tmin__74': 250, 'precip__74': 0, 'tmax__74': 356, 'site_id__74': 'USC00110072'}
# 2026-01-20 17:37:25,120 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, precip) VALUES (%(site_id__0)s, %(date__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(precip__2)s)
# 2026-01-20 17:37:25,120 INFO sqlalchemy.engine.Engine [generated in 0.00008s (insertmanyvalues) 1/1 (unordered)] {'precip__0': 0, 'site_id__0': 'USC00110072', 'date__0': Timestamp('1991-07-23 00:00:00'), 'precip__1': 0, 'site_id__1': 'USC00110072', 'date__1': Timestamp('1991-07-24 00:00:00'), 'precip__2': 0, 'site_id__2': 'USC00110072', 'date__2': Timestamp('1991-07-25 00:00:00')}
# 2026-01-20 17:37:25,122 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, precip) VALUES (%(site_id)s, %(date)s, %(tmax)s, %(precip)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,123 INFO sqlalchemy.engine.Engine [cached since 0.08503s ago] {'site_id': 'USC00110072', 'date': Timestamp('1991-07-26 00:00:00'), 'tmax': 250, 'precip': 0}
# 2026-01-20 17:37:25,125 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 585 characters truncated ... __10)s, %(precip__10)s), (%(site_id__11)s, %(date__11)s, %(tmax__11)s, %(tmin__11)s, %(precip__11)s)
# 2026-01-20 17:37:25,126 INFO sqlalchemy.engine.Engine [cached since 0.09045s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('1991-07-27 00:00:00'), 'tmin__0': 133, 'precip__0': 0, 'tmax__0': 250, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1991-07-28 00:00:00'), 'tmin__1': 133, 'precip__1': 0, 'tmax__1': 272, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1991-07-29 00:00:00'), 'tmin__2': 133, 'precip__2': 0, 'tmax__2': 272, 'site_id__2': 'USC00110072', 'date__3': Timestamp('1991-07-30 00:00:00'), 'tmin__3': 133, 'precip__3': 0, 'tmax__3': 261, 'site_id__3': 'USC00110072', 'date__4': Timestamp('1991-07-31 00:00:00'), 'tmin__4': 133, 'precip__4': 0, 'tmax__4': 261, 'site_id__4': 'USC00110072', 'date__5': Timestamp('1991-08-01 00:00:00'), 'tmin__5': 133, 'precip__5': 0, 'tmax__5': 317, 'site_id__5': 'USC00110072', 'date__6': Timestamp('1991-08-02 00:00:00'), 'tmin__6': 189, 'precip__6': 0, 'tmax__6': 344, 'site_id__6': 'USC00110072', 'date__7': Timestamp('1991-08-03 00:00:00'), 'tmin__7': 133, 'precip__7': 0, 'tmax__7': 356, 'site_id__7': 'USC00110072', 'date__8': Timestamp('1991-08-04 00:00:00'), 'tmin__8': 183, 'precip__8': 0, 'tmax__8': 250, 'site_id__8': 'USC00110072', 'date__9': Timestamp('1991-08-05 00:00:00'), 'tmin__9': 167, 'precip__9': 89, 'tmax__9': 250, 'site_id__9': 'USC00110072', 'date__10': Timestamp('1991-08-06 00:00:00'), 'tmin__10': 161, 'precip__10': 102, 'tmax__10': 250, 'site_id__10': 'USC00110072', 'date__11': Timestamp('1991-08-07 00:00:00'), 'tmin__11': 161, 'precip__11': 84, 'tmax__11': 278, 'site_id__11': 'USC00110072'}
# 2026-01-20 17:37:25,130 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, precip) VALUES (%(site_id)s, %(date)s, %(precip)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,130 INFO sqlalchemy.engine.Engine [generated in 0.00079s] {'site_id': 'USC00110072', 'date': Timestamp('1991-08-08 00:00:00'), 'precip': 0}
# 2026-01-20 17:37:25,132 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(precip__1)s)
# 2026-01-20 17:37:25,133 INFO sqlalchemy.engine.Engine [generated in 0.00006s (insertmanyvalues) 1/1 (unordered)] {'tmax__0': 261, 'site_id__0': 'USC00110072', 'date__0': Timestamp('1991-08-09 00:00:00'), 'precip__0': 0, 'tmax__1': 261, 'site_id__1': 'USC00110072', 'date__1': Timestamp('1991-08-10 00:00:00'), 'precip__1': 0}
# 2026-01-20 17:37:25,136 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 1432 characters truncated ... __21)s, %(precip__21)s), (%(site_id__22)s, %(date__22)s, %(tmax__22)s, %(tmin__22)s, %(precip__22)s)
# 2026-01-20 17:37:25,136 INFO sqlalchemy.engine.Engine [cached since 0.1013s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('1991-08-11 00:00:00'), 'tmin__0': 156, 'precip__0': 0, 'tmax__0': 272, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1991-08-12 00:00:00'), 'tmin__1': 156, 'precip__1': 0, 'tmax__1': 278, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1991-08-13 00:00:00'), 'tmin__2': 161, 'precip__2': 0, 'tmax__2': 283, 'site_id__2': 'USC00110072', 'date__3': Timestamp('1991-08-14 00:00:00'), 'tmin__3': 144, 'precip__3': 0, 'tmax__3': 272, 'site_id__3': 'USC00110072', 'date__4': Timestamp('1991-08-15 00:00:00'), 'tmin__4': 156, 'precip__4': 0, 'tmax__4': 289, 'site_id__4': 'USC00110072', 'date__5': Timestamp('1991-08-16 00:00:00'), 'tmin__5': 150, 'precip__5': 0, 'tmax__5': 294, 'site_id__5': 'USC00110072', 'date__6': Timestamp('1991-08-17 00:00:00'), 'tmin__6': 194, 'precip__6': 152, 'tmax__6': 272, 'site_id__6': 'USC00110072', 'date__7': Timestamp('1991-08-18 00:00:00'), 'tmin__7': 161, 'precip__7': 0, 'tmax__7': 278, 'site_id__7': 'USC00110072', 'date__8': Timestamp('1991-08-19 00:00:00'), 'tmin__8': 150, 'precip__8': 0, 'tmax__8': 278, 'site_id__8': 'USC00110072', 'date__9': Timestamp('1991-08-20 00:00:00'), 'tmin__9': 139, 'precip__9': 0, 'tmax__9': 278, 'site_id__9': 'USC00110072' ... 15 parameters truncated ... 'date__13': Timestamp('1991-08-24 00:00:00'), 'tmin__13': 183, 'precip__13': 0, 'tmax__13': 317, 'site_id__13': 'USC00110072', 'date__14': Timestamp('1991-08-25 00:00:00'), 'tmin__14': 183, 'precip__14': 0, 'tmax__14': 328, 'site_id__14': 'USC00110072', 'date__15': Timestamp('1991-08-26 00:00:00'), 'tmin__15': 183, 'precip__15': 0, 'tmax__15': 328, 'site_id__15': 'USC00110072', 'date__16': Timestamp('1991-08-27 00:00:00'), 'tmin__16': 183, 'precip__16': 0, 'tmax__16': 328, 'site_id__16': 'USC00110072', 'date__17': Timestamp('1991-08-28 00:00:00'), 'tmin__17': 183, 'precip__17': 0, 'tmax__17': 328, 'site_id__17': 'USC00110072', 'date__18': Timestamp('1991-08-29 00:00:00'), 'tmin__18': 222, 'precip__18': 0, 'tmax__18': 306, 'site_id__18': 'USC00110072', 'date__19': Timestamp('1991-08-30 00:00:00'), 'tmin__19': 200, 'precip__19': 13, 'tmax__19': 306, 'site_id__19': 'USC00110072', 'date__20': Timestamp('1991-08-31 00:00:00'), 'tmin__20': 200, 'precip__20': 0, 'tmax__20': 306, 'site_id__20': 'USC00110072', 'date__21': Timestamp('1991-09-01 00:00:00'), 'tmin__21': 150, 'precip__21': 0, 'tmax__21': 278, 'site_id__21': 'USC00110072', 'date__22': Timestamp('1991-09-02 00:00:00'), 'tmin__22': 150, 'precip__22': 0, 'tmax__22': 300, 'site_id__22': 'USC00110072'}
# 2026-01-20 17:37:25,138 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, precip) VALUES (%(site_id)s, %(date)s, %(precip)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,139 INFO sqlalchemy.engine.Engine [cached since 0.009466s ago] {'site_id': 'USC00110072', 'date': Timestamp('1991-09-03 00:00:00'), 'precip': 53}
# 2026-01-20 17:37:25,140 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s, %(tmin__2)s, %(precip__2)s)
# 2026-01-20 17:37:25,141 INFO sqlalchemy.engine.Engine [cached since 0.1062s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('1991-09-04 00:00:00'), 'tmin__0': 139, 'precip__0': 0, 'tmax__0': 256, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1991-09-05 00:00:00'), 'tmin__1': 117, 'precip__1': 0, 'tmax__1': 261, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1991-09-06 00:00:00'), 'tmin__2': 117, 'precip__2': 0, 'tmax__2': 294, 'site_id__2': 'USC00110072'}
# 2026-01-20 17:37:25,143 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date) VALUES (%(site_id)s, %(date)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,144 INFO sqlalchemy.engine.Engine [generated in 0.00121s] {'site_id': 'USC00110072', 'date': Timestamp('1991-09-07 00:00:00')}
# 2026-01-20 17:37:25,147 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin) VALUES (%(site_id)s, %(date)s, %(tmax)s, %(tmin)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,148 INFO sqlalchemy.engine.Engine [generated in 0.00133s] {'site_id': 'USC00110072', 'date': Timestamp('1991-09-08 00:00:00'), 'tmax': 311, 'tmin': 117}
# 2026-01-20 17:37:25,150 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, precip) VALUES (%(site_id)s, %(date)s, %(precip)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,151 INFO sqlalchemy.engine.Engine [cached since 0.02152s ago] {'site_id': 'USC00110072', 'date': Timestamp('1991-09-09 00:00:00'), 'precip': 51}
# 2026-01-20 17:37:25,153 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 5590 characters truncated ... __75)s, %(precip__75)s), (%(site_id__76)s, %(date__76)s, %(tmax__76)s, %(tmin__76)s, %(precip__76)s)
# 2026-01-20 17:37:25,154 INFO sqlalchemy.engine.Engine [cached since 0.1188s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('1991-09-10 00:00:00'), 'tmin__0': 200, 'precip__0': 0, 'tmax__0': 267, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1991-09-11 00:00:00'), 'tmin__1': 167, 'precip__1': 69, 'tmax__1': 267, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1991-09-12 00:00:00'), 'tmin__2': 167, 'precip__2': 0, 'tmax__2': 328, 'site_id__2': 'USC00110072', 'date__3': Timestamp('1991-09-13 00:00:00'), 'tmin__3': 167, 'precip__3': 0, 'tmax__3': 328, 'site_id__3': 'USC00110072', 'date__4': Timestamp('1991-09-14 00:00:00'), 'tmin__4': 222, 'precip__4': 0, 'tmax__4': 311, 'site_id__4': 'USC00110072', 'date__5': Timestamp('1991-09-15 00:00:00'), 'tmin__5': 217, 'precip__5': 0, 'tmax__5': 289, 'site_id__5': 'USC00110072', 'date__6': Timestamp('1991-09-16 00:00:00'), 'tmin__6': 167, 'precip__6': 53, 'tmax__6': 222, 'site_id__6': 'USC00110072', 'date__7': Timestamp('1991-09-17 00:00:00'), 'tmin__7': 100, 'precip__7': 0, 'tmax__7': 272, 'site_id__7': 'USC00110072', 'date__8': Timestamp('1991-09-18 00:00:00'), 'tmin__8': 100, 'precip__8': 76, 'tmax__8': 272, 'site_id__8': 'USC00110072', 'date__9': Timestamp('1991-09-19 00:00:00'), 'tmin__9': 28, 'precip__9': 0, 'tmax__9': 133, 'site_id__9': 'USC00110072' ... 285 parameters truncated ... 'date__67': Timestamp('1991-11-16 00:00:00'), 'tmin__67': 28, 'precip__67': 0, 'tmax__67': 139, 'site_id__67': 'USC00110072', 'date__68': Timestamp('1991-11-17 00:00:00'), 'tmin__68': 39, 'precip__68': 104, 'tmax__68': 111, 'site_id__68': 'USC00110072', 'date__69': Timestamp('1991-11-18 00:00:00'), 'tmin__69': 100, 'precip__69': 132, 'tmax__69': 178, 'site_id__69': 'USC00110072', 'date__70': Timestamp('1991-11-19 00:00:00'), 'tmin__70': 72, 'precip__70': 0, 'tmax__70': 133, 'site_id__70': 'USC00110072', 'date__71': Timestamp('1991-11-20 00:00:00'), 'tmin__71': 39, 'precip__71': 53, 'tmax__71': 133, 'site_id__71': 'USC00110072', 'date__72': Timestamp('1991-11-21 00:00:00'), 'tmin__72': -28, 'precip__72': 0, 'tmax__72': 122, 'site_id__72': 'USC00110072', 'date__73': Timestamp('1991-11-22 00:00:00'), 'tmin__73': 0, 'precip__73': 0, 'tmax__73': 83, 'site_id__73': 'USC00110072', 'date__74': Timestamp('1991-11-23 00:00:00'), 'tmin__74': -61, 'precip__74': 71, 'tmax__74': 61, 'site_id__74': 'USC00110072', 'date__75': Timestamp('1991-11-24 00:00:00'), 'tmin__75': -94, 'precip__75': 0, 'tmax__75': -56, 'site_id__75': 'USC00110072', 'date__76': Timestamp('1991-11-25 00:00:00'), 'tmin__76': -144, 'precip__76': 0, 'tmax__76': -56, 'site_id__76': 'USC00110072'}
# 2026-01-20 17:37:25,157 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date) VALUES (%(site_id)s, %(date)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,158 INFO sqlalchemy.engine.Engine [cached since 0.01432s ago] {'site_id': 'USC00110072', 'date': Timestamp('1991-11-26 00:00:00')}
# 2026-01-20 17:37:25,159 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin) VALUES (%(site_id)s, %(date)s, %(tmax)s, %(tmin)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,160 INFO sqlalchemy.engine.Engine [cached since 0.01285s ago] {'site_id': 'USC00110072', 'date': Timestamp('1991-11-27 00:00:00'), 'tmax': 72, 'tmin': 17}
# 2026-01-20 17:37:25,161 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s, %(tmin__2)s, %(precip__2)s)
# 2026-01-20 17:37:25,162 INFO sqlalchemy.engine.Engine [cached since 0.1269s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('1991-11-28 00:00:00'), 'tmin__0': 6, 'precip__0': 81, 'tmax__0': 39, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1991-11-29 00:00:00'), 'tmin__1': 6, 'precip__1': 38, 'tmax__1': 167, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1991-11-30 00:00:00'), 'tmin__2': -39, 'precip__2': 114, 'tmax__2': 144, 'site_id__2': 'USC00110072'}
# 2026-01-20 17:37:25,163 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin) VALUES (%(site_id)s, %(date)s, %(tmax)s, %(tmin)s) RETURNING wxtable.id
# 2026-01-20 17:37:25,164 INFO sqlalchemy.engine.Engine [cached since 0.01708s ago] {'site_id': 'USC00110072', 'date': Timestamp('1991-12-01 00:00:00'), 'tmax': -33, 'tmin': -94}
# 2026-01-20 17:37:25,167 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 6668 characters truncated ... __89)s, %(precip__89)s), (%(site_id__90)s, %(date__90)s, %(tmax__90)s, %(tmin__90)s, %(precip__90)s)
# 2026-01-20 17:37:25,168 INFO sqlalchemy.engine.Engine [cached since 0.1321s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('1991-12-02 00:00:00'), 'tmin__0': -39, 'precip__0': 0, 'tmax__0': -28, 'site_id__0': 'USC00110072', 'date__1': Timestamp('1991-12-03 00:00:00'), 'tmin__1': -128, 'precip__1': 140, 'tmax__1': -28, 'site_id__1': 'USC00110072', 'date__2': Timestamp('1991-12-04 00:00:00'), 'tmin__2': -200, 'precip__2': 0, 'tmax__2': -128, 'site_id__2': 'USC00110072', 'date__3': Timestamp('1991-12-05 00:00:00'), 'tmin__3': -139, 'precip__3': 0, 'tmax__3': 44, 'site_id__3': 'USC00110072', 'date__4': Timestamp('1991-12-06 00:00:00'), 'tmin__4': -128, 'precip__4': 0, 'tmax__4': 28, 'site_id__4': 'USC00110072', 'date__5': Timestamp('1991-12-07 00:00:00'), 'tmin__5': 28, 'precip__5': 0, 'tmax__5': 83, 'site_id__5': 'USC00110072', 'date__6': Timestamp('1991-12-08 00:00:00'), 'tmin__6': 28, 'precip__6': 30, 'tmax__6': 183, 'site_id__6': 'USC00110072', 'date__7': Timestamp('1991-12-09 00:00:00'), 'tmin__7': -39, 'precip__7': 0, 'tmax__7': 67, 'site_id__7': 'USC00110072', 'date__8': Timestamp('1991-12-10 00:00:00'), 'tmin__8': -39, 'precip__8': 0, 'tmax__8': 111, 'site_id__8': 'USC00110072', 'date__9': Timestamp('1991-12-11 00:00:00'), 'tmin__9': -39, 'precip__9': 0, 'tmax__9': 111, 'site_id__9': 'USC00110072' ... 355 parameters truncated ... 'date__81': Timestamp('1992-02-21 00:00:00'), 'tmin__81': -33, 'precip__81': 0, 'tmax__81': 94, 'site_id__81': 'USC00110072', 'date__82': Timestamp('1992-02-22 00:00:00'), 'tmin__82': -6, 'precip__82': 0, 'tmax__82': 106, 'site_id__82': 'USC00110072', 'date__83': Timestamp('1992-02-23 00:00:00'), 'tmin__83': 11, 'precip__83': 0, 'tmax__83': 100, 'site_id__83': 'USC00110072', 'date__84': Timestamp('1992-02-24 00:00:00'), 'tmin__84': 17, 'precip__84': 114, 'tmax__84': 78, 'site_id__84': 'USC00110072', 'date__85': Timestamp('1992-02-25 00:00:00'), 'tmin__85': -33, 'precip__85': 13, 'tmax__85': 22, 'site_id__85': 'USC00110072', 'date__86': Timestamp('1992-02-26 00:00:00'), 'tmin__86': -50, 'precip__86': 0, 'tmax__86': 78, 'site_id__86': 'USC00110072', 'date__87': Timestamp('1992-02-27 00:00:00'), 'tmin__87': -11, 'precip__87': 0, 'tmax__87': 61, 'site_id__87': 'USC00110072', 'date__88': Timestamp('1992-02-28 00:00:00'), 'tmin__88': 0, 'precip__88': 0, 'tmax__88': 111, 'site_id__88': 'USC00110072', 'date__89': Timestamp('1992-02-29 00:00:00'), 'tmin__89': -28, 'precip__89': 0, 'tmax__89': 78, 'site_id__89': 'USC00110072', 'date__90': Timestamp('1992-03-01 00:00:00'), 'tmin__90': 11, 'precip__90': 0, 'tmax__90': 217, 'site_id__90': 'USC00110072'}
# 2026-01-20 17:37:25,172 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, precip) VALUES (%(site_id__0)s, %(date__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(precip__1)s)
# 2026-01-20 17:37:25,173 INFO sqlalchemy.engine.Engine [cached since 0.05264s ago (insertmanyvalues) 1/1 (unordered)] {'precip__0': 0, 'site_id__0': 'USC00110072', 'date__0': Timestamp('1992-03-02 00:00:00'), 'precip__1': 0, 'site_id__1': 'USC00110072', 'date__1': Timestamp('1992-03-03 00:00:00')}
# 2026-01-20 17:37:25,175 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 4204 characters truncated ... __57)s, %(precip__57)s), (%(site_id__58)s, %(date__58)s, %(tmax__58)s, %(tmin__58)s, %(precip__58)s)
# ...
# 2026-01-20 17:37:28,333 INFO sqlalchemy.engine.Engine [cached since 3.213s ago (insertmanyvalues) 1/1 (unordered)] {'precip__0': 0, 'site_id__0': 'USC00111280', 'date__0': Timestamp('2007-06-01 00:00:00'), 'precip__1': 0, 'site_id__1': 'USC00111280', 'date__1': Timestamp('2007-06-02 00:00:00'), 'precip__2': 0, 'site_id__2': 'USC00111280', 'date__2': Timestamp('2007-06-03 00:00:00'), 'precip__3': 0, 'site_id__3': 'USC00111280', 'date__3': Timestamp('2007-06-04 00:00:00'), 'precip__4': 0, 'site_id__4': 'USC00111280', 'date__4': Timestamp('2007-06-05 00:00:00'), 'precip__5': 0, 'site_id__5': 'USC00111280', 'date__5': Timestamp('2007-06-06 00:00:00')}
# 2026-01-20 17:37:28,335 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 6206 characters truncated ... __83)s, %(precip__83)s), (%(site_id__84)s, %(date__84)s, %(tmax__84)s, %(tmin__84)s, %(precip__84)s)
# 2026-01-20 17:37:28,336 INFO sqlalchemy.engine.Engine [cached since 3.301s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('2007-06-07 00:00:00'), 'tmin__0': 206, 'precip__0': 0, 'tmax__0': 311, 'site_id__0': 'USC00111280', 'date__1': Timestamp('2007-06-08 00:00:00'), 'tmin__1': 222, 'precip__1': 5, 'tmax__1': 322, 'site_id__1': 'USC00111280', 'date__2': Timestamp('2007-06-09 00:00:00'), 'tmin__2': 100, 'precip__2': 0, 'tmax__2': 244, 'site_id__2': 'USC00111280', 'date__3': Timestamp('2007-06-10 00:00:00'), 'tmin__3': 117, 'precip__3': 0, 'tmax__3': 244, 'site_id__3': 'USC00111280', 'date__4': Timestamp('2007-06-11 00:00:00'), 'tmin__4': 156, 'precip__4': 0, 'tmax__4': 233, 'site_id__4': 'USC00111280', 'date__5': Timestamp('2007-06-12 00:00:00'), 'tmin__5': 139, 'precip__5': 0, 'tmax__5': 283, 'site_id__5': 'USC00111280', 'date__6': Timestamp('2007-06-13 00:00:00'), 'tmin__6': 133, 'precip__6': 0, 'tmax__6': 300, 'site_id__6': 'USC00111280', 'date__7': Timestamp('2007-06-14 00:00:00'), 'tmin__7': 156, 'precip__7': 0, 'tmax__7': 306, 'site_id__7': 'USC00111280', 'date__8': Timestamp('2007-06-15 00:00:00'), 'tmin__8': 172, 'precip__8': 0, 'tmax__8': 322, 'site_id__8': 'USC00111280', 'date__9': Timestamp('2007-06-16 00:00:00'), 'tmin__9': 172, 'precip__9': 0, 'tmax__9': 322, 'site_id__9': 'USC00111280' ... 325 parameters truncated ... 'date__75': Timestamp('2007-08-21 00:00:00'), 'tmin__75': 228, 'precip__75': 3, 'tmax__75': 294, 'site_id__75': 'USC00111280', 'date__76': Timestamp('2007-08-22 00:00:00'), 'tmin__76': 217, 'precip__76': 10, 'tmax__76': 344, 'site_id__76': 'USC00111280', 'date__77': Timestamp('2007-08-23 00:00:00'), 'tmin__77': 233, 'precip__77': 0, 'tmax__77': 356, 'site_id__77': 'USC00111280', 'date__78': Timestamp('2007-08-24 00:00:00'), 'tmin__78': 217, 'precip__78': 201, 'tmax__78': 322, 'site_id__78': 'USC00111280', 'date__79': Timestamp('2007-08-25 00:00:00'), 'tmin__79': 139, 'precip__79': 5, 'tmax__79': 283, 'site_id__79': 'USC00111280', 'date__80': Timestamp('2007-08-26 00:00:00'), 'tmin__80': 156, 'precip__80': 0, 'tmax__80': 300, 'site_id__80': 'USC00111280', 'date__81': Timestamp('2007-08-27 00:00:00'), 'tmin__81': 194, 'precip__81': 0, 'tmax__81': 333, 'site_id__81': 'USC00111280', 'date__82': Timestamp('2007-08-28 00:00:00'), 'tmin__82': 189, 'precip__82': 0, 'tmax__82': 361, 'site_id__82': 'USC00111280', 'date__83': Timestamp('2007-08-29 00:00:00'), 'tmin__83': 206, 'precip__83': 0, 'tmax__83': 356, 'site_id__83': 'USC00111280', 'date__84': Timestamp('2007-08-30 00:00:00'), 'tmin__84': 100, 'precip__84': 0, 'tmax__84': 300, 'site_id__84': 'USC00111280'}
# 2026-01-20 17:37:28,340 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, precip) VALUES (%(site_id)s, %(date)s, %(precip)s) RETURNING wxtable.id
# 2026-01-20 17:37:28,341 INFO sqlalchemy.engine.Engine [cached since 3.212s ago] {'site_id': 'USC00111280', 'date': Timestamp('2007-08-31 00:00:00'), 'precip': 0}
# 2026-01-20 17:37:28,343 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 6283 characters truncated ... __84)s, %(precip__84)s), (%(site_id__85)s, %(date__85)s, %(tmax__85)s, %(tmin__85)s, %(precip__85)s)
# 2026-01-20 17:37:28,344 INFO sqlalchemy.engine.Engine [cached since 3.309s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('2007-09-01 00:00:00'), 'tmin__0': 111, 'precip__0': 0, 'tmax__0': 289, 'site_id__0': 'USC00111280', 'date__1': Timestamp('2007-09-02 00:00:00'), 'tmin__1': 111, 'precip__1': 0, 'tmax__1': 300, 'site_id__1': 'USC00111280', 'date__2': Timestamp('2007-09-03 00:00:00'), 'tmin__2': 122, 'precip__2': 0, 'tmax__2': 328, 'site_id__2': 'USC00111280', 'date__3': Timestamp('2007-09-04 00:00:00'), 'tmin__3': 150, 'precip__3': 0, 'tmax__3': 350, 'site_id__3': 'USC00111280', 'date__4': Timestamp('2007-09-05 00:00:00'), 'tmin__4': 178, 'precip__4': 0, 'tmax__4': 356, 'site_id__4': 'USC00111280', 'date__5': Timestamp('2007-09-06 00:00:00'), 'tmin__5': 206, 'precip__5': 25, 'tmax__5': 317, 'site_id__5': 'USC00111280', 'date__6': Timestamp('2007-09-07 00:00:00'), 'tmin__6': 211, 'precip__6': 41, 'tmax__6': 267, 'site_id__6': 'USC00111280', 'date__7': Timestamp('2007-09-08 00:00:00'), 'tmin__7': 206, 'precip__7': 5, 'tmax__7': 289, 'site_id__7': 'USC00111280', 'date__8': Timestamp('2007-09-09 00:00:00'), 'tmin__8': 194, 'precip__8': 28, 'tmax__8': 261, 'site_id__8': 'USC00111280', 'date__9': Timestamp('2007-09-10 00:00:00'), 'tmin__9': 150, 'precip__9': 0, 'tmax__9': 311, 'site_id__9': 'USC00111280' ... 330 parameters truncated ... 'date__76': Timestamp('2007-11-16 00:00:00'), 'tmin__76': -17, 'precip__76': 0, 'tmax__76': 72, 'site_id__76': 'USC00111280', 'date__77': Timestamp('2007-11-17 00:00:00'), 'tmin__77': 6, 'precip__77': 0, 'tmax__77': 106, 'site_id__77': 'USC00111280', 'date__78': Timestamp('2007-11-18 00:00:00'), 'tmin__78': 11, 'precip__78': 0, 'tmax__78': 172, 'site_id__78': 'USC00111280', 'date__79': Timestamp('2007-11-19 00:00:00'), 'tmin__79': 11, 'precip__79': 0, 'tmax__79': 106, 'site_id__79': 'USC00111280', 'date__80': Timestamp('2007-11-20 00:00:00'), 'tmin__80': 106, 'precip__80': 0, 'tmax__80': 222, 'site_id__80': 'USC00111280', 'date__81': Timestamp('2007-11-21 00:00:00'), 'tmin__81': 83, 'precip__81': 0, 'tmax__81': 217, 'site_id__81': 'USC00111280', 'date__82': Timestamp('2007-11-22 00:00:00'), 'tmin__82': 6, 'precip__82': 0, 'tmax__82': 89, 'site_id__82': 'USC00111280', 'date__83': Timestamp('2007-11-23 00:00:00'), 'tmin__83': -22, 'precip__83': 0, 'tmax__83': 17, 'site_id__83': 'USC00111280', 'date__84': Timestamp('2007-11-24 00:00:00'), 'tmin__84': -33, 'precip__84': 0, 'tmax__84': 22, 'site_id__84': 'USC00111280', 'date__85': Timestamp('2007-11-25 00:00:00'), 'tmin__85': -44, 'precip__85': 0, 'tmax__85': 39, 'site_id__85': 'USC00111280'}
# 2026-01-20 17:37:28,347 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s)
# 2026-01-20 17:37:28,348 INFO sqlalchemy.engine.Engine [cached since 3.236s ago (insertmanyvalues) 1/1 (unordered)] {'tmax__0': 17, 'site_id__0': 'USC00111280', 'date__0': Timestamp('2007-11-26 00:00:00'), 'tmin__0': 0, 'tmax__1': 44, 'site_id__1': 'USC00111280', 'date__1': Timestamp('2007-11-27 00:00:00'), 'tmin__1': -22}
# 2026-01-20 17:37:28,351 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 14659 characters truncated ... , %(precip__187)s), (%(site_id__188)s, %(date__188)s, %(tmax__188)s, %(tmin__188)s, %(precip__188)s)
# 2026-01-20 17:37:28,351 INFO sqlalchemy.engine.Engine [cached since 3.316s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('2007-11-28 00:00:00'), 'tmin__0': 0, 'precip__0': 0, 'tmax__0': 89, 'site_id__0': 'USC00111280', 'date__1': Timestamp('2007-11-29 00:00:00'), 'tmin__1': -44, 'precip__1': 3, 'tmax__1': 144, 'site_id__1': 'USC00111280', 'date__2': Timestamp('2007-11-30 00:00:00'), 'tmin__2': -39, 'precip__2': 0, 'tmax__2': 56, 'site_id__2': 'USC00111280', 'date__3': Timestamp('2007-12-01 00:00:00'), 'tmin__3': -56, 'precip__3': 0, 'tmax__3': 39, 'site_id__3': 'USC00111280', 'date__4': Timestamp('2007-12-02 00:00:00'), 'tmin__4': -22, 'precip__4': 5, 'tmax__4': 133, 'site_id__4': 'USC00111280', 'date__5': Timestamp('2007-12-03 00:00:00'), 'tmin__5': -67, 'precip__5': 79, 'tmax__5': 161, 'site_id__5': 'USC00111280', 'date__6': Timestamp('2007-12-04 00:00:00'), 'tmin__6': -67, 'precip__6': 0, 'tmax__6': 17, 'site_id__6': 'USC00111280', 'date__7': Timestamp('2007-12-05 00:00:00'), 'tmin__7': -33, 'precip__7': 3, 'tmax__7': 61, 'site_id__7': 'USC00111280', 'date__8': Timestamp('2007-12-06 00:00:00'), 'tmin__8': -100, 'precip__8': 0, 'tmax__8': 17, 'site_id__8': 'USC00111280', 'date__9': Timestamp('2007-12-07 00:00:00'), 'tmin__9': -72, 'precip__9': 74, 'tmax__9': -11, 'site_id__9': 'USC00111280' ... 845 parameters truncated ... 'date__179': Timestamp('2008-05-25 00:00:00'), 'tmin__179': 128, 'precip__179': 18, 'tmax__179': 217, 'site_id__179': 'USC00111280', 'date__180': Timestamp('2008-05-26 00:00:00'), 'tmin__180': 144, 'precip__180': 427, 'tmax__180': 244, 'site_id__180': 'USC00111280', 'date__181': Timestamp('2008-05-27 00:00:00'), 'tmin__181': 161, 'precip__181': 0, 'tmax__181': 267, 'site_id__181': 'USC00111280', 'date__182': Timestamp('2008-05-28 00:00:00'), 'tmin__182': 89, 'precip__182': 0, 'tmax__182': 233, 'site_id__182': 'USC00111280', 'date__183': Timestamp('2008-05-29 00:00:00'), 'tmin__183': 83, 'precip__183': 0, 'tmax__183': 217, 'site_id__183': 'USC00111280', 'date__184': Timestamp('2008-05-30 00:00:00'), 'tmin__184': 139, 'precip__184': 0, 'tmax__184': 261, 'site_id__184': 'USC00111280', 'date__185': Timestamp('2008-05-31 00:00:00'), 'tmin__185': 183, 'precip__185': 0, 'tmax__185': 306, 'site_id__185': 'USC00111280', 'date__186': Timestamp('2008-06-01 00:00:00'), 'tmin__186': 156, 'precip__186': 0, 'tmax__186': 294, 'site_id__186': 'USC00111280', 'date__187': Timestamp('2008-06-02 00:00:00'), 'tmin__187': 156, 'precip__187': 0, 'tmax__187': 300, 'site_id__187': 'USC00111280', 'date__188': Timestamp('2008-06-03 00:00:00'), 'tmin__188': 189, 'precip__188': 330, 'tmax__188': 289, 'site_id__188': 'USC00111280'}
# 2026-01-20 17:37:28,358 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin) VALUES (%(site_id)s, %(date)s, %(tmax)s, %(tmin)s) RETURNING wxtable.id
# 2026-01-20 17:37:28,359 INFO sqlalchemy.engine.Engine [cached since 3.212s ago] {'site_id': 'USC00111280', 'date': Timestamp('2008-06-04 00:00:00'), 'tmax': 294, 'tmin': 194}
# 2026-01-20 17:37:28,360 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s)
# 2026-01-20 17:37:28,360 INFO sqlalchemy.engine.Engine [cached since 3.326s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('2008-06-05 00:00:00'), 'tmin__0': 200, 'precip__0': 0, 'tmax__0': 311, 'site_id__0': 'USC00111280', 'date__1': Timestamp('2008-06-06 00:00:00'), 'tmin__1': 244, 'precip__1': 0, 'tmax__1': 311, 'site_id__1': 'USC00111280'}
# 2026-01-20 17:37:28,362 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s, %(tmin__2)s)
# 2026-01-20 17:37:28,363 INFO sqlalchemy.engine.Engine [cached since 3.251s ago (insertmanyvalues) 1/1 (unordered)] {'tmax__0': 278, 'site_id__0': 'USC00111280', 'date__0': Timestamp('2008-06-07 00:00:00'), 'tmin__0': 217, 'tmax__1': 322, 'site_id__1': 'USC00111280', 'date__1': Timestamp('2008-06-08 00:00:00'), 'tmin__1': 228, 'tmax__2': 333, 'site_id__2': 'USC00111280', 'date__2': Timestamp('2008-06-09 00:00:00'), 'tmin__2': 189}
# 2026-01-20 17:37:28,364 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmax, tmin, precip) VALUES (%(site_id__0)s, %(date__0)s, %(tmax__0)s, %(tmin__0)s, %(precip__0)s), (%(site_id__1)s, %(date__1)s, %(tmax__1)s, %(tmin__1)s, %(precip__1)s), (%(site_id__2)s, %(date__2)s, %(tmax__2)s,  ... 1971 characters truncated ... __28)s, %(precip__28)s), (%(site_id__29)s, %(date__29)s, %(tmax__29)s, %(tmin__29)s, %(precip__29)s)
# 2026-01-20 17:37:28,365 INFO sqlalchemy.engine.Engine [cached since 3.329s ago (insertmanyvalues) 1/1 (unordered)] {'date__0': Timestamp('2008-06-10 00:00:00'), 'tmin__0': 167, 'precip__0': 20, 'tmax__0': 261, 'site_id__0': 'USC00111280', 'date__1': Timestamp('2008-06-11 00:00:00'), 'tmin__1': 183, 'precip__1': 0, 'tmax__1': 289, 'site_id__1': 'USC00111280', 'date__2': Timestamp('2008-06-12 00:00:00'), 'tmin__2': 217, 'precip__2': 0, 'tmax__2': 294, 'site_id__2': 'USC00111280', 'date__3': Timestamp('2008-06-13 00:00:00'), 'tmin__3': 206, 'precip__3': 0, 'tmax__3': 328, 'site_id__3': 'USC00111280', 'date__4': Timestamp('2008-06-14 00:00:00'), 'tmin__4': 167, 'precip__4': 20, 'tmax__4': 244, 'site_id__4': 'USC00111280', 'date__5': Timestamp('2008-06-15 00:00:00'), 'tmin__5': 172, 'precip__5': 0, 'tmax__5': 294, 'site_id__5': 'USC00111280', 'date__6': Timestamp('2008-06-16 00:00:00'), 'tmin__6': 172, 'precip__6': 0, 'tmax__6': 311, 'site_id__6': 'USC00111280', 'date__7': Timestamp('2008-06-17 00:00:00'), 'tmin__7': 144, 'precip__7': 0, 'tmax__7': 261, 'site_id__7': 'USC00111280', 'date__8': Timestamp('2008-06-18 00:00:00'), 'tmin__8': 128, 'precip__8': 0, 'tmax__8': 250, 'site_id__8': 'USC00111280', 'date__9': Timestamp('2008-06-19 00:00:00'), 'tmin__9': 144, 'precip__9': 25, 'tmax__9': 272, 'site_id__9': 'USC00111280' ... 50 parameters truncated ... 'date__20': Timestamp('2008-06-30 00:00:00'), 'tmin__20': 150, 'precip__20': 33, 'tmax__20': 233, 'site_id__20': 'USC00111280', 'date__21': Timestamp('2008-07-01 00:00:00'), 'tmin__21': 139, 'precip__21': 0, 'tmax__21': 267, 'site_id__21': 'USC00111280', 'date__22': Timestamp('2008-07-02 00:00:00'), 'tmin__22': 194, 'precip__22': 0, 'tmax__22': 283, 'site_id__22': 'USC00111280', 'date__23': Timestamp('2008-07-03 00:00:00'), 'tmin__23': 189, 'precip__23': 180, 'tmax__23': 311, 'site_id__23': 'USC00111280', 'date__24': Timestamp('2008-07-04 00:00:00'), 'tmin__24': 144, 'precip__24': 13, 'tmax__24': 222, 'site_id__24': 'USC00111280', 'date__25': Timestamp('2008-07-05 00:00:00'), 'tmin__25': 139, 'precip__25': 0, 'tmax__25': 244, 'site_id__25': 'USC00111280', 'date__26': Timestamp('2008-07-06 00:00:00'), 'tmin__26': 139, 'precip__26': 0, 'tmax__26': 261, 'site_id__26': 'USC00111280', 'date__27': Timestamp('2008-07-07 00:00:00'), 'tmin__27': 189, 'precip__27': 0, 'tmax__27': 306, 'site_id__27': 'USC00111280', 'date__28': Timestamp('2008-07-08 00:00:00'), 'tmin__28': 239, 'precip__28': 0, 'tmax__28': 311, 'site_id__28': 'USC00111280', 'date__29': Timestamp('2008-07-09 00:00:00'), 'tmin__29': 200, 'precip__29': 376, 'tmax__29': 311, 'site_id__29': 'USC00111280'}
# 2026-01-20 17:37:28,366 INFO sqlalchemy.engine.Engine INSERT INTO wxtable (site_id, date, tmin, precip) VALUES (%(site_id)s, %(date)s, %(tmin)s, %(precip)s) RETURNING wxtable.id

# %% [markdown]
# ## Reading from database

# %%
# %%time
import os
import pandas as pd
from main import main
from database import engine
main()
# Out:
# CPU times: user 2min 18s, sys: 1.08 s, total: 2min 19s
# Wall time: 2min 37s

# %%
pd.read_sql()

# %%
df = pd.read_sql("SELECT * FROM WxTable;", con = engine)
print("---")
print(df)
# Out:
# 2026-01-19 19:09:20,299 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-19 19:09:20,302 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2026-01-19 19:09:20,306 INFO sqlalchemy.engine.Engine [cached since 22.53s ago] {'table_name': 'SELECT * FROM WxTable;', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2026-01-19 19:09:20,311 INFO sqlalchemy.engine.Engine SELECT * FROM WxTable;
# 2026-01-19 19:09:20,313 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-01-19 19:09:20,599 INFO sqlalchemy.engine.Engine ROLLBACK
# ---
#             id      site_id       date   tmax   tmin  precip
# 0            1  USC00110072 1985-01-01  -22.0 -128.0    94.0
# 1            2  USC00110072 1985-01-02 -122.0 -217.0     0.0
# 2            3  USC00110072 1985-01-03 -106.0 -244.0     0.0
# 3            4  USC00110072 1985-01-04  -56.0 -189.0     0.0
# 4            5  USC00110072 1985-01-05   11.0  -78.0     0.0
# ...        ...          ...        ...    ...    ...     ...
# 104907  104908  USC00113335 2014-11-26  -33.0 -106.0     0.0
# 104908  104909  USC00113335 2014-11-27  -22.0  -67.0     0.0
# 104909  104910  USC00113335 2014-11-28  -22.0 -139.0     0.0
# 104910  104911  USC00113335 2014-11-29   17.0  -89.0     0.0
# 104911  104912  USC00113335 2014-11-30  111.0   17.0     0.0
#
# [104912 rows x 6 columns]

# %% [markdown]
# # Create WxTable Statistics

# %%
from functions import read_wxdata
import pandas as pd
from pathlib import Path

df = read_wxdata(Path("/code/wx_data/USC00110338.txt"))

# %%
# Out:
#             date  tmax  tmin precip      site_id
# 0     1985-01-01    11  -122    348  USC00110338
# 1     1985-01-02  -106  -183      3  USC00110338
# 2     1985-01-03   -56  -183      0  USC00110338
# 3     1985-01-04   -17  -161      0  USC00110338
# 4     1985-01-05    17   -61      0  USC00110338
# ...          ...   ...   ...    ...          ...
# 10707 2014-12-27   106   -50      0  USC00110338
# 10708 2014-12-28    89   -56      0  USC00110338
# 10709 2014-12-29    17   -56      0  USC00110338
# 10710 2014-12-30    -6  -122      0  USC00110338
# 10711 2014-12-31   -72  -161      0  USC00110338
#
# [10712 rows x 5 columns]

# %% [markdown]
# ## Check for multiple records

# %%
for f in Path("/code/wx_data/").glob("USC*.txt"):
    df = read_wxdata(f)
    ind = df["date"].duplicated()
    if not df[ind].empty:
        print(df[ind])

# %% [markdown]
# ## Calculating aggregate stats

# %%
import numpy as np
df.groupby(["site_id", df["date"].dt.year])\
  .agg(
      tmax_yearly   = ("tmax", "mean"),
      tmin_yearly   = ("tmin", "mean"),
      precip_yearly = ("precip", "sum") )\
  .reset_index()
# Out:
#         site_id  date tmax_yearly  tmin_yearly  precip_yearly
# 0   USC00339312  1985  141.060274    39.550685          10067
# 1   USC00339312  1986  150.860274    51.315068           9476
# 2   USC00339312  1987  156.630137    52.794521           8115
# 3   USC00339312  1988  152.224044    36.622951           8982
# 4   USC00339312  1989  145.173077    39.808219          10183
# 5   USC00339312  1990  161.915068    55.720548          13540
# 6   USC00339312  1991   168.29589    57.487671           7417
# 7   USC00339312  1992  145.218579    44.680328          10898
# 8   USC00339312  1993  149.523288    45.810959           9987
# 9   USC00339312  1994  152.005479    40.169863           9471
# 10  USC00339312  1995  147.087671    42.558904          10792
# 11  USC00339312  1996  142.308743    40.109290          13285
# 12  USC00339312  1997  145.030137    40.334247           8715
# 13  USC00339312  1998  163.528767    61.010959          10316
# 14  USC00339312  1999  155.487671    45.693151           8836
# 15  USC00339312  2000  139.557377    42.726776          10389
# 16  USC00339312  2001  148.446575    54.657534           9469
# 17  USC00339312  2002  160.326027    48.347945           8892
# 18  USC00339312  2003  145.347945    38.531507          11918
# 19  USC00339312  2004  148.967213    42.185792          13375
# 20  USC00339312  2005  153.652055    44.249315          10544
# 21  USC00339312  2006   159.10137    53.501370          11391
# 22  USC00339312  2007  159.082192    46.887671          11539
# 23  USC00339312  2008   154.10929    36.775956          11382
# 24  USC00339312  2009       154.8    34.419178          10596
# 25  USC00339312  2010  161.676712    43.347945          10340
# 26  USC00339312  2011  163.076712    50.460274          13607
# 27  USC00339312  2012  177.983607    51.650273           9108
# 28  USC00339312  2013  154.736986    40.183562          10990
# 29  USC00339312  2014  147.038356    28.783562           9943
